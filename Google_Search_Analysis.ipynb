# %%
# !pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (2.1.0)
# Requirement already satisfied: lxml in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (4.9.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\vk269\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   56
# Singapore                  53
# India                      41
# Pakistan                   30
# Tunisia                    30
# Hong Kong                  30
# Sri Lanka                  26
# South Korea                24
# Kenya                      24
# C:\Users\vk269\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytrends\request.py:355: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   result_df = df['value'].apply(lambda x: pd.Series(

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Search Analysis for Machine Learning' , fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
# Out:
# C:\Users\vk269\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytrends\request.py:247: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   result_df = df['value'].apply(lambda x: pd.Series(
# C:\Users\vk269\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytrends\request.py:261: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   result_df2 = df['isPartial'].apply(lambda x: pd.Series(
